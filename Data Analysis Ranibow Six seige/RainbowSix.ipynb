# %% [markdown]
# # Loading the libraries

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing files as DataFrames

# %%
import glob
all_files = glob.glob('C:/Users/SRINIVAS/Downloads/archive (2)/datadump*.csv')
all_files
# Out:
# ['C:/Users/SRINIVAS/Downloads/archive (2)\\datadump_s5-000.csv',
#  'C:/Users/SRINIVAS/Downloads/archive (2)\\datadump_s5-001.csv',
#  'C:/Users/SRINIVAS/Downloads/archive (2)\\datadump_s5-002.csv',
#  'C:/Users/SRINIVAS/Downloads/archive (2)\\datadump_s5-003.csv',
#  'C:/Users/SRINIVAS/Downloads/archive (2)\\datadump_s5-004.csv',
#  'C:/Users/SRINIVAS/Downloads/archive (2)\\datadump_s5-005.csv',
#  'C:/Users/SRINIVAS/Downloads/archive (2)\\datadump_s5-006.csv',
#  'C:/Users/SRINIVAS/Downloads/archive (2)\\datadump_s5-007.csv',
#  'C:/Users/SRINIVAS/Downloads/archive (2)\\datadump_s5-008.csv',
#  'C:/Users/SRINIVAS/Downloads/archive (2)\\datadump_s5-009.csv',
#  'C:/Users/SRINIVAS/Downloads/archive (2)\\datadump_s5-010.csv',
#  'C:/Users/SRINIVAS/Downloads/archive (2)\\datadump_s5-011.csv',
#  'C:/Users/SRINIVAS/Downloads/archive (2)\\datadump_s5-012.csv',
#  'C:/Users/SRINIVAS/Downloads/archive (2)\\datadump_s5-013.csv',
#  'C:/Users/SRINIVAS/Downloads/archive (2)\\datadump_s5-014.csv',
#  'C:/Users/SRINIVAS/Downloads/archive (2)\\datadump_s5-015.csv',
#  'C:/Users/SRINIVAS/Downloads/archive (2)\\datadump_s5-016.csv',
#  'C:/Users/SRINIVAS/Downloads/archive (2)\\datadump_s5-017.csv',
#  'C:/Users/SRINIVAS/Downloads/archive (2)\\datadump_s5-018.csv',
#  'C:/Users/SRINIVAS/Downloads/archive (2)\\datadump_s5-019.csv',
#  'C:/Users/SRINIVAS/Downloads/archive (2)\\datadump_s5-020.csv',
#  'C:/Users/SRINIVAS/Downloads/archive (2)\\datadump_s5-021.csv']

# %%
li = []

for filename in all_files[3:5]:
    frame = pd.read_csv(filename, index_col=None, header=0)
    li.append(frame)

df = pd.concat(li, axis='rows', ignore_index=True)
df
# Out:
#            dateid platform     gamemode mapname     matchid  roundnumber  \
# 0        20170223      PS4  SECURE_AREA   HOUSE   977823561            5
# 1        20170223      PS4  SECURE_AREA   HOUSE   977823561            1
# 2        20170223      PS4  SECURE_AREA   HOUSE   977823561            3
# 3        20170223      PS4  SECURE_AREA   HOUSE   977823561            2
# 4        20170223      PS4  SECURE_AREA   HOUSE   977823561            2
# ...           ...      ...          ...     ...         ...          ...
# 7999995  20170310     XONE  SECURE_AREA   HOUSE  4213607369            6
# 7999996  20170310     XONE  SECURE_AREA   HOUSE  4213607369            3
# 7999997  20170310     XONE  SECURE_AREA   HOUSE  4213607369            1
# 7999998  20170310     XONE  SECURE_AREA   HOUSE  4213607369            1
# 7999999  20170310     XONE  SECURE_AREA   HOUSE  4213607369            6
#
#         objectivelocation   winrole       endroundreason  roundduration  ...  \
# 0           KID'S_BEDROOM  Attacker  DefendersEliminated            185  ...
# 1          MASTER_BEDROOM  Attacker  DefendersEliminated            181  ...
# 2          MASTER_BEDROOM  Defender  AttackersEliminated            225  ...
# 3                  GARAGE  Defender  AttackersEliminated            221  ...
# 4                  GARAGE  Defender  AttackersEliminated            221  ...
# ...                   ...       ...                  ...            ...  ...
# 7999995     KID'S_BEDROOM  Defender  AttackersEliminated            186  ...
# 7999996     KID'S_BEDROOM  Attacker  DefendersEliminated            160  ...
# 7999997            GARAGE  Defender  AttackersEliminated            177  ...
# 7999998            GARAGE  Defender  AttackersEliminated            177  ...
# 7999999     KID'S_BEDROOM  Defender  AttackersEliminated            186  ...
#
#          primarygrip primaryunderbarrel primarybarrel  secondaryweapon  \
# 0               None               None   HeavyBarrel            PRB92
# 1           Vertical              Laser   MuzzleBrake           ITA12S
# 2               None               None   HeavyBarrel            PRB92
# 3              Angle               None   Compensator            USP40
# 4           Vertical               None   HeavyBarrel            PRB92
# ...              ...                ...           ...              ...
# 7999995     Vertical              Laser   Compensator               P9
# 7999996     Vertical               None   Compensator           SMG-11
# 7999997         None               None          None              P12
# 7999998         None               None          None            PRB92
# 7999999     Vertical               None          None       M45_MEUSOC
#
#          secondaryweapontype secondarysight  secondarygrip  \
# 0                    Pistols           None           None
# 1                   Shotguns           None           None
# 2                    Pistols           None           None
# 3                    Pistols           None           None
# 4                    Pistols           None           None
# ...                      ...            ...            ...
# 7999995              Pistols           None           None
# 7999996      Submachine_Guns         RedDot       Vertical
# 7999997              Pistols           None           None
# 7999998              Pistols           None           None
# 7999999              Pistols           None           None
#
#          secondaryunderbarrel secondarybarrel secondarygadget
# 0                       Laser            None  IMPACT_GRENADE
# 1                        None            None   BREACH_CHARGE
# 2                       Laser            None  IMPACT_GRENADE
# 3                        None            None   BREACH_CHARGE
# 4                        None     MuzzleBrake        CLAYMORE
# ...                       ...             ...             ...
# 7999995                  None            None   BREACH_CHARGE
# 7999996                  None     HeavyBarrel    FRAG_GRENADE
# 7999997                  None            None     BARBED_WIRE
# 7999998                  None            None  IMPACT_GRENADE
# 7999999                  None            None  IMPACT_GRENADE
#
# [8000000 rows x 31 columns]

# %%
#since the files are very large I have loaded 2 datasets randomly

# %%
df.columns
# Out:
# Index(['dateid', 'platform', 'gamemode', 'mapname', 'matchid', 'roundnumber',
#        'objectivelocation', 'winrole', 'endroundreason', 'roundduration',
#        'clearancelevel', 'skillrank', 'role', 'team', 'haswon', 'operator',
#        'nbkills', 'isdead', 'primaryweapon', 'primaryweapontype',
#        'primarysight', 'primarygrip', 'primaryunderbarrel', 'primarybarrel',
#        'secondaryweapon', 'secondaryweapontype', 'secondarysight',
#        'secondarygrip', 'secondaryunderbarrel', 'secondarybarrel',
#        'secondarygadget'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000000 entries, 0 to 7999999
# Data columns (total 31 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   dateid                int64
#  1   platform              object
#  2   gamemode              object
#  3   mapname               object
#  4   matchid               int64
#  5   roundnumber           int64
#  6   objectivelocation     object
#  7   winrole               object
#  8   endroundreason        object
#  9   roundduration         int64
#  10  clearancelevel        int64
#  11  skillrank             object
#  12  role                  object
#  13  team                  int64
#  14  haswon                int64
#  15  operator              object
#  16  nbkills               int64
#  17  isdead                int64
#  18  primaryweapon         object
#  19  primaryweapontype     object
#  20  primarysight          object
#  21  primarygrip           object
#  22  primaryunderbarrel    object
#  23  primarybarrel         object
#  24  secondaryweapon       object
#  25  secondaryweapontype   object
#  26  secondarysight        object
#  27  secondarygrip         object
#  28  secondaryunderbarrel  object
#  29  secondarybarrel       object
#  30  secondarygadget       object
# dtypes: int64(9), object(22)
# memory usage: 1.8+ GB

# %%
df.isnull().sum()
# Out:
# dateid                  0
# platform                0
# gamemode                0
# mapname                 0
# matchid                 0
# roundnumber             0
# objectivelocation       0
# winrole                 0
# endroundreason          0
# roundduration           0
# clearancelevel          0
# skillrank               0
# role                    0
# team                    0
# haswon                  0
# operator                0
# nbkills                 0
# isdead                  0
# primaryweapon           0
# primaryweapontype       0
# primarysight            0
# primarygrip             0
# primaryunderbarrel      0
# primarybarrel           0
# secondaryweapon         0
# secondaryweapontype     0
# secondarysight          0
# secondarygrip           0
# secondaryunderbarrel    0
# secondarybarrel         0
# secondarygadget         0
# dtype: int64

# %%
df.describe()
# Out:
#              dateid       matchid   roundnumber  roundduration  \
# count  8.000000e+06  8.000000e+06  8.000000e+06   8.000000e+06
# mean   2.017031e+07  2.089185e+09  3.602075e+00   1.861265e+02
# std    8.482036e+01  1.238073e+09  2.039396e+00   4.448442e+01
# min    2.017021e+07  1.028100e+04  1.000000e+00   6.000000e+00
# 25%    2.017023e+07  1.023760e+09  2.000000e+00   1.550000e+02
# 50%    2.017031e+07  2.068021e+09  3.000000e+00   1.890000e+02
# 75%    2.017032e+07  3.146467e+09  5.000000e+00   2.220000e+02
# max    2.017051e+07  4.294954e+09  9.000000e+00   1.274400e+04
#
#        clearancelevel          team        haswon       nbkills        isdead
# count    8.000000e+06  8.000000e+06  8.000000e+06  8.000000e+06  8.000000e+06
# mean     9.514382e+01  4.997941e-01  5.089100e-01  7.003635e-01  7.037007e-01
# std      4.703130e+01  5.000000e-01  4.999206e-01  9.239960e-01  4.566246e-01
# min      0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%      6.000000e+01  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%      9.000000e+01  0.000000e+00  1.000000e+00  0.000000e+00  1.000000e+00
# 75%      1.250000e+02  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# max      5.870000e+02  1.000000e+00  1.000000e+00  8.000000e+00  1.000000e+00

# %%
df.describe(include=['O'])
# Out:
#        platform     gamemode  mapname objectivelocation   winrole  \
# count   8000000      8000000  8000000           8000000   8000000
# unique        3            3       16               142         2
# top         PS4  SECURE_AREA    HOUSE            GARAGE  Defender
# freq    4248739      5241657   522005            328387   4004777
#
#              endroundreason skillrank      role    operator  primaryweapon  \
# count               8000000   8000000   8000000     8000000        8000000
# unique                   15         7         2          35             46
# top     DefendersEliminated      Gold  Defender  GSG9-JAGER  416-C_CARBINE
# freq                3594397   2896615   4015497      540882         543861
#
#         ... primarygrip primaryunderbarrel primarybarrel secondaryweapon  \
# count   ...     8000000            8000000       8000000         8000000
# unique  ...           4                  3             7              16
# top     ...    Vertical               None   MuzzleBrake             P12
# freq    ...     4581246            6701015       1953401         1172426
#
#        secondaryweapontype secondarysight secondarygrip secondaryunderbarrel  \
# count              8000000        8000000       8000000              8000000
# unique                   3              5             3                    4
# top                Pistols           None          None                 None
# freq               6573947        6815301       7456620              6517570
#
#        secondarybarrel secondarygadget
# count          8000000         8000000
# unique               7               9
# top               None   BREACH_CHARGE
# freq           4987115         1465118
#
# [4 rows x 22 columns]

# %%
#comparing gamemode and the map(mapname) that players are getting

# %%
df.gamemode.unique()
# Out:
# array(['SECURE_AREA', 'BOMB', 'HOSTAGE'], dtype=object)

# %%
df.mapname.unique()
# Out:
# array(['HOUSE', 'YACHT', 'BORDER', 'KAFE_DOSTOYEVSKY', 'KANAL',
#        'CONSULATE', 'BANK', 'CLUB_HOUSE', 'CHALET', 'OREGON',
#        'SKYSCRAPER', 'BARTLETT_U.', 'FAVELAS', 'COASTLINE', 'PLANE',
#        'HEREFORD_BASE'], dtype=object)

# %%
# dividing them by game mode
sec_gm = df[df['gamemode'] == 'SECURE_AREA']
bom_gm = df[df['gamemode'] == 'BOMB']
hos_gm = df[df['gamemode'] == 'HOSTAGE']

# %%
#grouping them with respect to maps
sec_map_count = sec_gm.groupby('mapname')['gamemode'].count()
bom_map_count = bom_gm.groupby('mapname')['gamemode'].count()
hos_map_count = hos_gm.groupby('mapname')['gamemode'].count()
print(sec_map_count,bom_map_count,hos_map_count)
# Out:
# mapname
# BANK                331349
# BARTLETT_U.         315341
# BORDER              326648
# CHALET              333427
# CLUB_HOUSE          333488
# COASTLINE           275230
# CONSULATE           329952
# FAVELAS             323756
# HEREFORD_BASE       339600
# HOUSE               343430
# KAFE_DOSTOYEVSKY    332803
# KANAL               329868
# OREGON              334148
# PLANE               322889
# SKYSCRAPER          339599
# YACHT               330129
# Name: gamemode, dtype: int64 mapname
# BANK                118886
# BARTLETT_U.         120981
# BORDER              125095
# CHALET              120872
# CLUB_HOUSE          123921
# COASTLINE           101392
# CONSULATE           118684
# FAVELAS             116395
# HEREFORD_BASE       122544
# HOUSE               120874
# KAFE_DOSTOYEVSKY    124106
# KANAL               118248
# OREGON              119356
# PLANE               118654
# SKYSCRAPER          122839
# YACHT               118284
# Name: gamemode, dtype: int64 mapname
# BANK                53766
# BARTLETT_U.         55518
# BORDER              52114
# CHALET              53109
# CLUB_HOUSE          54196
# COASTLINE           45851
# CONSULATE           52001
# FAVELAS             51841
# HEREFORD_BASE       54871
# HOUSE               57701
# KAFE_DOSTOYEVSKY    50362
# KANAL               52453
# OREGON              52310
# PLANE               52383
# SKYSCRAPER          53859
# YACHT               54877
# Name: gamemode, dtype: int64

# %%
hos_map_count.index
# Out:
# Index(['BANK', 'BARTLETT_U.', 'BORDER', 'CHALET', 'CLUB_HOUSE', 'COASTLINE',
#        'CONSULATE', 'FAVELAS', 'HEREFORD_BASE', 'HOUSE', 'KAFE_DOSTOYEVSKY',
#        'KANAL', 'OREGON', 'PLANE', 'SKYSCRAPER', 'YACHT'],
#       dtype='object', name='mapname')

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(16)
width = 0.2
  
# plot data in grouped manner of bar type
plt.figure(figsize=(20,20))
plt.barh(x-0.2, sec_map_count, width, color='cyan')
plt.barh(x, bom_map_count, width, color='orange')
plt.barh(x+0.2, hos_map_count, width, color='green')
plt.yticks(x, hos_map_count.index)
plt.title('Map Count for Each Gamemode')
plt.legend(['SECURE_AREA', 'BOMB', 'HOSTAGE'])
plt.show()

# %%
# we can see that the hostage is the least and bomb is the second most and the secure area gamemode is the most played

# %%
'''so the possiblities are either the game algorithm is selecting secure area more times 
or 
the number of rounds players play is more in securearea which could 
mean that it is either attackers win or the defenders win'''
#so now comparing the winrole with the gamemode as the second case could mean that we need changes accordingly
# Out:
# 'so the possiblities are either the game algorithm is selecting secure area more times \nor \nthe number of rounds players play is more in securearea which could \nmean that it is either attackers win or the defenders win'

# %%
sec_role_count = sec_gm.groupby('winrole')['gamemode'].count()
bom_role_count = bom_gm.groupby('winrole')['gamemode'].count()
hos_role_count = hos_gm.groupby('winrole')['gamemode'].count()
print(sec_role_count,bom_role_count,hos_role_count)
# Out:
# winrole
# Attacker    2647331
# Defender    2594326
# Name: gamemode, dtype: int64 winrole
# Attacker    955128
# Defender    956003
# Name: gamemode, dtype: int64 winrole
# Attacker    392764
# Defender    454448
# Name: gamemode, dtype: int64

# %%
y = np.arange(2)

width = 0.20


fig, ax = plt.subplots(figsize=(10,10))
rects1 = ax.barh(y - width, sec_role_count, width, label='SECURE_AREA')
rects2 = ax.barh(y, bom_role_count, width, label='BOMB')
rects3 = ax.barh(y + width, hos_role_count, width, label='HOSTAGE')


ax.set_title('Role Count for Each Gamemode')
ax.set_yticks(y, hos_role_count.index)
ax.legend(loc='best')
ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)
plt.show()

# %%
'''Everygame mode is almost equal for both attackers and defenders whereas the hostage mode we can see that 
the defenders are comparitively winning more so rules could be a little bit changed to make it equally difficult'''
# Out:
# 'Everygame mode is almost equal for both attackers and defenders whereas the hostage mode we can see that \nthe defenders are comparitively winning more so rules could be a little bit changed to make it equally difficult'

# %%
# 2) which operators are taken frequently and which are the least preferred ones
# this could be very useful and can buff and nerf in the future patches accordingly

# %%
df.groupby('operator').count()
# Out:
#                      dateid  platform  gamemode  mapname  matchid  \
# operator
# BOPE-CAPITAO         123113    123113    123113   123113   123113
# BOPE-CAVEIRA         362881    362881    362881   362881   362881
# G.E.O.-JACKAL        335600    335600    335600   335600   335600
# G.E.O.-MIRA          268986    268986    268986   268986   268986
# GIGN-DOC             218811    218811    218811   218811   218811
# GIGN-MONTAGNE        140137    140137    140137   140137   140137
# GIGN-RESERVE          13995     13995     13995    13995    13995
# GIGN-ROOK            261890    261890    261890   261890   261890
# GIGN-TWITCH          390928    390928    390928   390928   390928
# GSG9-BANDIT          400048    400048    400048   400048   400048
# GSG9-BLITZ            59520     59520     59520    59520    59520
# GSG9-IQ              124295    124295    124295   124295   124295
# GSG9-JAGER           540882    540882    540882   540882   540882
# GSG9-RESERVE          47681     47681     47681    47681    47681
# JTF2-BUCK            186781    186781    186781   186781   186781
# JTF2-FROST           271786    271786    271786   271786   271786
# NAVYSEAL-BLACKBEARD  144567    144567    144567   144567   144567
# NAVYSEAL-VALKYRIE    323472    323472    323472   323472   323472
# SAS-MUTE             305448    305448    305448   305448   305448
# SAS-RESERVE           32148     32148     32148    32148    32148
# SAS-SLEDGE           307905    307905    307905   307905   307905
# SAS-SMOKE            264878    264878    264878   264878   264878
# SAS-THATCHER         243420    243420    243420   243420   243420
# SAT-ECHO              85625     85625     85625    85625    85625
# SAT-HIBANA           387329    387329    387329   387329   387329
# SPETSNAZ-FUZE        351101    351101    351101   351101   351101
# SPETSNAZ-GLAZ        260567    260567    260567   260567   260567
# SPETSNAZ-KAPKAN      176230    176230    176230   176230   176230
# SPETSNAZ-RESERVE      13141     13141     13141    13141    13141
# SPETSNAZ-TACHANKA     32600     32600     32600    32600    32600
# SWAT-ASH             493068    493068    493068   493068   493068
# SWAT-CASTLE          168662    168662    168662   168662   168662
# SWAT-PULSE           265389    265389    265389   265389   265389
# SWAT-RESERVE          16469     16469     16469    16469    16469
# SWAT-THERMITE        380647    380647    380647   380647   380647
#
#                      roundnumber  objectivelocation  winrole  endroundreason  \
# operator
# BOPE-CAPITAO              123113             123113   123113          123113
# BOPE-CAVEIRA              362881             362881   362881          362881
# G.E.O.-JACKAL             335600             335600   335600          335600
# G.E.O.-MIRA               268986             268986   268986          268986
# GIGN-DOC                  218811             218811   218811          218811
# GIGN-MONTAGNE             140137             140137   140137          140137
# GIGN-RESERVE               13995              13995    13995           13995
# GIGN-ROOK                 261890             261890   261890          261890
# GIGN-TWITCH               390928             390928   390928          390928
# GSG9-BANDIT               400048             400048   400048          400048
# GSG9-BLITZ                 59520              59520    59520           59520
# GSG9-IQ                   124295             124295   124295          124295
# GSG9-JAGER                540882             540882   540882          540882
# GSG9-RESERVE               47681              47681    47681           47681
# JTF2-BUCK                 186781             186781   186781          186781
# JTF2-FROST                271786             271786   271786          271786
# NAVYSEAL-BLACKBEARD       144567             144567   144567          144567
# NAVYSEAL-VALKYRIE         323472             323472   323472          323472
# SAS-MUTE                  305448             305448   305448          305448
# SAS-RESERVE                32148              32148    32148           32148
# SAS-SLEDGE                307905             307905   307905          307905
# SAS-SMOKE                 264878             264878   264878          264878
# SAS-THATCHER              243420             243420   243420          243420
# SAT-ECHO                   85625              85625    85625           85625
# SAT-HIBANA                387329             387329   387329          387329
# SPETSNAZ-FUZE             351101             351101   351101          351101
# SPETSNAZ-GLAZ             260567             260567   260567          260567
# SPETSNAZ-KAPKAN           176230             176230   176230          176230
# SPETSNAZ-RESERVE           13141              13141    13141           13141
# SPETSNAZ-TACHANKA          32600              32600    32600           32600
# SWAT-ASH                  493068             493068   493068          493068
# SWAT-CASTLE               168662             168662   168662          168662
# SWAT-PULSE                265389             265389   265389          265389
# SWAT-RESERVE               16469              16469    16469           16469
# SWAT-THERMITE             380647             380647   380647          380647
#
#                      roundduration  ...  primarygrip  primaryunderbarrel  \
# operator                            ...
# BOPE-CAPITAO                123113  ...       123113              123113
# BOPE-CAVEIRA                362881  ...       362881              362881
# G.E.O.-JACKAL               335600  ...       335600              335600
# G.E.O.-MIRA                 268986  ...       268986              268986
# GIGN-DOC                    218811  ...       218811              218811
# GIGN-MONTAGNE               140137  ...       140137              140137
# GIGN-RESERVE                 13995  ...        13995               13995
# GIGN-ROOK                   261890  ...       261890              261890
# GIGN-TWITCH                 390928  ...       390928              390928
# GSG9-BANDIT                 400048  ...       400048              400048
# GSG9-BLITZ                   59520  ...        59520               59520
# GSG9-IQ                     124295  ...       124295              124295
# GSG9-JAGER                  540882  ...       540882              540882
# GSG9-RESERVE                 47681  ...        47681               47681
# JTF2-BUCK                   186781  ...       186781              186781
# JTF2-FROST                  271786  ...       271786              271786
# NAVYSEAL-BLACKBEARD         144567  ...       144567              144567
# NAVYSEAL-VALKYRIE           323472  ...       323472              323472
# SAS-MUTE                    305448  ...       305448              305448
# SAS-RESERVE                  32148  ...        32148               32148
# SAS-SLEDGE                  307905  ...       307905              307905
# SAS-SMOKE                   264878  ...       264878              264878
# SAS-THATCHER                243420  ...       243420              243420
# SAT-ECHO                     85625  ...        85625               85625
# SAT-HIBANA                  387329  ...       387329              387329
# SPETSNAZ-FUZE               351101  ...       351101              351101
# SPETSNAZ-GLAZ               260567  ...       260567              260567
# SPETSNAZ-KAPKAN             176230  ...       176230              176230
# SPETSNAZ-RESERVE             13141  ...        13141               13141
# SPETSNAZ-TACHANKA            32600  ...        32600               32600
# SWAT-ASH                    493068  ...       493068              493068
# SWAT-CASTLE                 168662  ...       168662              168662
# SWAT-PULSE                  265389  ...       265389              265389
# SWAT-RESERVE                 16469  ...        16469               16469
# SWAT-THERMITE               380647  ...       380647              380647
#
#                      primarybarrel  secondaryweapon  secondaryweapontype  \
# operator
# BOPE-CAPITAO                123113           123113               123113
# BOPE-CAVEIRA                362881           362881               362881
# G.E.O.-JACKAL               335600           335600               335600
# G.E.O.-MIRA                 268986           268986               268986
# GIGN-DOC                    218811           218811               218811
# GIGN-MONTAGNE               140137           140137               140137
# GIGN-RESERVE                 13995            13995                13995
# GIGN-ROOK                   261890           261890               261890
# GIGN-TWITCH                 390928           390928               390928
# GSG9-BANDIT                 400048           400048               400048
# GSG9-BLITZ                   59520            59520                59520
# GSG9-IQ                     124295           124295               124295
# GSG9-JAGER                  540882           540882               540882
# GSG9-RESERVE                 47681            47681                47681
# JTF2-BUCK                   186781           186781               186781
# JTF2-FROST                  271786           271786               271786
# NAVYSEAL-BLACKBEARD         144567           144567               144567
# NAVYSEAL-VALKYRIE           323472           323472               323472
# SAS-MUTE                    305448           305448               305448
# SAS-RESERVE                  32148            32148                32148
# SAS-SLEDGE                  307905           307905               307905
# SAS-SMOKE                   264878           264878               264878
# SAS-THATCHER                243420           243420               243420
# SAT-ECHO                     85625            85625                85625
# SAT-HIBANA                  387329           387329               387329
# SPETSNAZ-FUZE               351101           351101               351101
# SPETSNAZ-GLAZ               260567           260567               260567
# SPETSNAZ-KAPKAN             176230           176230               176230
# SPETSNAZ-RESERVE             13141            13141                13141
# SPETSNAZ-TACHANKA            32600            32600                32600
# SWAT-ASH                    493068           493068               493068
# SWAT-CASTLE                 168662           168662               168662
# SWAT-PULSE                  265389           265389               265389
# SWAT-RESERVE                 16469            16469                16469
# SWAT-THERMITE               380647           380647               380647
#
#                      secondarysight  secondarygrip  secondaryunderbarrel  \
# operator
# BOPE-CAPITAO                 123113         123113                123113
# BOPE-CAVEIRA                 362881         362881                362881
# G.E.O.-JACKAL                335600         335600                335600
# G.E.O.-MIRA                  268986         268986                268986
# GIGN-DOC                     218811         218811                218811
# GIGN-MONTAGNE                140137         140137                140137
# GIGN-RESERVE                  13995          13995                 13995
# GIGN-ROOK                    261890         261890                261890
# GIGN-TWITCH                  390928         390928                390928
# GSG9-BANDIT                  400048         400048                400048
# GSG9-BLITZ                    59520          59520                 59520
# GSG9-IQ                      124295         124295                124295
# GSG9-JAGER                   540882         540882                540882
# GSG9-RESERVE                  47681          47681                 47681
# JTF2-BUCK                    186781         186781                186781
# JTF2-FROST                   271786         271786                271786
# NAVYSEAL-BLACKBEARD          144567         144567                144567
# NAVYSEAL-VALKYRIE            323472         323472                323472
# SAS-MUTE                     305448         305448                305448
# SAS-RESERVE                   32148          32148                 32148
# SAS-SLEDGE                   307905         307905                307905
# SAS-SMOKE                    264878         264878                264878
# SAS-THATCHER                 243420         243420                243420
# SAT-ECHO                      85625          85625                 85625
# SAT-HIBANA                   387329         387329                387329
# SPETSNAZ-FUZE                351101         351101                351101
# SPETSNAZ-GLAZ                260567         260567                260567
# SPETSNAZ-KAPKAN              176230         176230                176230
# SPETSNAZ-RESERVE              13141          13141                 13141
# SPETSNAZ-TACHANKA             32600          32600                 32600
# SWAT-ASH                     493068         493068                493068
# SWAT-CASTLE                  168662         168662                168662
# SWAT-PULSE                   265389         265389                265389
# SWAT-RESERVE                  16469          16469                 16469
# SWAT-THERMITE                380647         380647                380647
#
#                      secondarybarrel  secondarygadget
# operator
# BOPE-CAPITAO                  123113           123113
# BOPE-CAVEIRA                  362881           362881
# G.E.O.-JACKAL                 335600           335600
# G.E.O.-MIRA                   268986           268986
# GIGN-DOC                      218811           218811
# GIGN-MONTAGNE                 140137           140137
# GIGN-RESERVE                   13995            13995
# GIGN-ROOK                     261890           261890
# GIGN-TWITCH                   390928           390928
# GSG9-BANDIT                   400048           400048
# GSG9-BLITZ                     59520            59520
# GSG9-IQ                       124295           124295
# GSG9-JAGER                    540882           540882
# GSG9-RESERVE                   47681            47681
# JTF2-BUCK                     186781           186781
# JTF2-FROST                    271786           271786
# NAVYSEAL-BLACKBEARD           144567           144567
# NAVYSEAL-VALKYRIE             323472           323472
# SAS-MUTE                      305448           305448
# SAS-RESERVE                    32148            32148
# SAS-SLEDGE                    307905           307905
# SAS-SMOKE                     264878           264878
# SAS-THATCHER                  243420           243420
# SAT-ECHO                       85625            85625
# SAT-HIBANA                    387329           387329
# SPETSNAZ-FUZE                 351101           351101
# SPETSNAZ-GLAZ                 260567           260567
# SPETSNAZ-KAPKAN               176230           176230
# SPETSNAZ-RESERVE               13141            13141
# SPETSNAZ-TACHANKA              32600            32600
# SWAT-ASH                      493068           493068
# SWAT-CASTLE                   168662           168662
# SWAT-PULSE                    265389           265389
# SWAT-RESERVE                   16469            16469
# SWAT-THERMITE                 380647           380647
#
# [35 rows x 30 columns]

# %%
df.groupby('operator')['operator'].count()
# Out:
# operator
# BOPE-CAPITAO           123113
# BOPE-CAVEIRA           362881
# G.E.O.-JACKAL          335600
# G.E.O.-MIRA            268986
# GIGN-DOC               218811
# GIGN-MONTAGNE          140137
# GIGN-RESERVE            13995
# GIGN-ROOK              261890
# GIGN-TWITCH            390928
# GSG9-BANDIT            400048
# GSG9-BLITZ              59520
# GSG9-IQ                124295
# GSG9-JAGER             540882
# GSG9-RESERVE            47681
# JTF2-BUCK              186781
# JTF2-FROST             271786
# NAVYSEAL-BLACKBEARD    144567
# NAVYSEAL-VALKYRIE      323472
# SAS-MUTE               305448
# SAS-RESERVE             32148
# SAS-SLEDGE             307905
# SAS-SMOKE              264878
# SAS-THATCHER           243420
# SAT-ECHO                85625
# SAT-HIBANA             387329
# SPETSNAZ-FUZE          351101
# SPETSNAZ-GLAZ          260567
# SPETSNAZ-KAPKAN        176230
# SPETSNAZ-RESERVE        13141
# SPETSNAZ-TACHANKA       32600
# SWAT-ASH               493068
# SWAT-CASTLE            168662
# SWAT-PULSE             265389
# SWAT-RESERVE            16469
# SWAT-THERMITE          380647
# Name: operator, dtype: int64

# %%
#we can go with pie chart but I am not preferring it as there are lot of operator and data wont be proper so proceeding with barchart

# %%
plt.figure(figsize=(20,20))
plt.bar(df.groupby('operator')['operator'].count().index,df.groupby('operator')['operator'].count())
plt.xticks(rotation = 90)
plt.show()

# %%
# we can see jager(defender) and ash(attacker) are most preffered ones so they can be nerfed
# and also we can see that recruit aka reserve a basic operator is not preffered which is fine
# and also we can see tachanka(defender) and blitz(attacker) are least preffered ones so they can get a buff

# %%
# comparing map with round duration

# %%
round_dur_map = df.groupby('mapname')['roundduration'].mean().sort_values(ascending = False)

# %%
round_dur_map
# Out:
# mapname
# BARTLETT_U.         192.896611
# BANK                191.647094
# OREGON              189.798997
# CLUB_HOUSE          189.711203
# CONSULATE           189.580556
# KANAL               189.493007
# HEREFORD_BASE       187.909268
# KAFE_DOSTOYEVSKY    187.878560
# PLANE               187.342444
# COASTLINE           184.889465
# BORDER              184.259530
# YACHT               183.024594
# HOUSE               181.603751
# CHALET              181.422134
# SKYSCRAPER          180.184330
# FAVELAS             176.393326
# Name: roundduration, dtype: float64

# %%
'''From this data we can see that Bartlett and Bank is taking more time and Favela is taking less time
for a round, so the maps can be altered or the objective location could be made nearby or far to make them 
fall between 180 to 190 seconds
'''
# Out:
# 'From this data we can see that Bartlett and Bank is taking more time and Favela is taking less time\nfor a round, so the maps can be altered or the objective location could be made nearby or far to make them \nfall between 180 to 190 seconds\n'

# %%
# comparing objective location with duration

# %%
# For some maps the objective location names are same, so its better to use pivot table

# %%
pv_table = pd.pivot_table(df,index=['mapname', 'objectivelocation'],values='roundduration',aggfunc = 'mean').sort_values('roundduration',ascending=False)
pv_table
# Out:
#                                      roundduration
# mapname     objectivelocation
# BARTLETT_U. LIBRARY                     201.131483
#             CLASSROOM-LIBRARY           198.071277
# COASTLINE   2F_PENTHOUSE-2F_THEATER     196.869155
# BANK        VAULT                       196.498358
# CLUB_HOUSE  CHURCH                      196.432030
# ...                                            ...
# HOUSE       KID'S_BEDROOM               168.709865
# FAVELAS     3F_PACKAGING_ROOM           168.667296
# SKYSCRAPER  1F_KITCHEN                  168.256655
# HOUSE       DINING_ROOM                 167.421708
#             LIVING_ROOM                 164.551883
#
# [160 rows x 1 columns]

# %%
#Finding the objectives location for the time reduction steps by keeping a threshold of 190
pv_table[(pv_table['roundduration']>190) | (pv_table['roundduration']<180)]
# Out:
#                                      roundduration
# mapname     objectivelocation
# BARTLETT_U. LIBRARY                     201.131483
#             CLASSROOM-LIBRARY           198.071277
# COASTLINE   2F_PENTHOUSE-2F_THEATER     196.869155
# BANK        VAULT                       196.498358
# CLUB_HOUSE  CHURCH                      196.432030
# ...                                            ...
# HOUSE       KID'S_BEDROOM               168.709865
# FAVELAS     3F_PACKAGING_ROOM           168.667296
# SKYSCRAPER  1F_KITCHEN                  168.256655
# HOUSE       DINING_ROOM                 167.421708
#             LIVING_ROOM                 164.551883
#
# [89 rows x 1 columns]

# %%
pd.set_option('display.max_rows',100)

# %%
needed_pv_table = pv_table[(pv_table['roundduration']>190) | (pv_table['roundduration']<180)]

# %%
'''So for these objective the difficulty level should be reduced if it take more than 190 seconds 
and if its less than 180 second difficulty level should be increased'''
# Out:
# 'So for these objective the difficulty level should be reduced if it take more than 190 seconds \nand if its less than 180 second difficulty level should be increased'

# %%
# saving it as a csv file for future use

# %%
needed_pv_table.to_csv('changes_needed_objectivelocations')

# %%
pd.set_option('display.max_rows',10)

# %%
# comparing the endroundreason with objectivelocation

# %%
end_obj = pd.crosstab(df["objectivelocation"], df["endroundreason"])
end_obj
# Out:
# endroundreason                 AllTeamsDead  AttackersEliminated  \
# objectivelocation
# 1F_ARMORY_ROOM                           69                39539
# 1F_AUNT'S_APARTMENT                      64                21469
# 1F_BBQ                                   10                21241
# 1F_BBQ-1F_KITCHEN                         8                 5700
# 1F_BEDROOM                               85                24777
# ...                                     ...                  ...
# VENTILATION_ROOM-WORKSHOP                10                 9685
# VISA_OFFICE                              10                 5453
# WINE_CELLAR                               0                 9057
# WINE_CELLAR-SNOWMOBILE_GARAGE            64                17762
# WORKSHOP                                 66                54734
#
# endroundreason                 AttackersKilledHostage  AttackersSurrendered  \
# objectivelocation
# 1F_ARMORY_ROOM                                      0                   141
# 1F_AUNT'S_APARTMENT                                 0                   147
# 1F_BBQ                                              0                   113
# 1F_BBQ-1F_KITCHEN                                   0                    14
# 1F_BEDROOM                                        265                   129
# ...                                               ...                   ...
# VENTILATION_ROOM-WORKSHOP                           0                    34
# VISA_OFFICE                                         0                    16
# WINE_CELLAR                                       563                    19
# WINE_CELLAR-SNOWMOBILE_GARAGE                       0                   133
# WORKSHOP                                          642                   340
#
# endroundreason                 BombDeactivated_OneBomb  BombExploded  \
# objectivelocation
# 1F_ARMORY_ROOM                                       0             0
# 1F_AUNT'S_APARTMENT                                  0             0
# 1F_BBQ                                               0             0
# 1F_BBQ-1F_KITCHEN                                  310           605
# 1F_BEDROOM                                           0             0
# ...                                                ...           ...
# VENTILATION_ROOM-WORKSHOP                          656          1848
# VISA_OFFICE                                          0             0
# WINE_CELLAR                                          0             0
# WINE_CELLAR-SNOWMOBILE_GARAGE                     1252          3278
# WORKSHOP                                             0             0
#
# endroundreason                 DefendersEliminated  DefendersKilledHostage  \
# objectivelocation
# 1F_ARMORY_ROOM                               42707                       0
# 1F_AUNT'S_APARTMENT                          26115                       0
# 1F_BBQ                                       20376                       0
# 1F_BBQ-1F_KITCHEN                             7694                       0
# 1F_BEDROOM                                   27151                     207
# ...                                            ...                     ...
# VENTILATION_ROOM-WORKSHOP                    12031                       0
# VISA_OFFICE                                   7288                       0
# WINE_CELLAR                                   8448                     323
# WINE_CELLAR-SNOWMOBILE_GARAGE                27537                       0
# WORKSHOP                                     57964                     291
#
# endroundreason                 DefendersSurrendered  DefuserDeactivated  \
# objectivelocation
# 1F_ARMORY_ROOM                                   61                   0
# 1F_AUNT'S_APARTMENT                              42                   0
# 1F_BBQ                                           32                   0
# 1F_BBQ-1F_KITCHEN                                16                1159
# 1F_BEDROOM                                       67                   0
# ...                                             ...                 ...
# VENTILATION_ROOM-WORKSHOP                        25                2136
# VISA_OFFICE                                      39                   0
# WINE_CELLAR                                       6                   0
# WINE_CELLAR-SNOWMOBILE_GARAGE                   115                3182
# WORKSHOP                                        116                   0
#
# endroundreason                 HostageExtracted  NoEnemies  ObjectiveCaptured  \
# objectivelocation
# 1F_ARMORY_ROOM                                0          1               4892
# 1F_AUNT'S_APARTMENT                           0          2               3260
# 1F_BBQ                                        0          5               2940
# 1F_BBQ-1F_KITCHEN                             0          5                  0
# 1F_BEDROOM                                 1586          5               5052
# ...                                         ...        ...                ...
# VENTILATION_ROOM-WORKSHOP                     0          0                  0
# VISA_OFFICE                                   0          6               2224
# WINE_CELLAR                                1473          0                  0
# WINE_CELLAR-SNOWMOBILE_GARAGE                 0          5                  0
# WORKSHOP                                   1848         17               3533
#
# endroundreason                 ObjectiveProtected  TimeExpired
# objectivelocation
# 1F_ARMORY_ROOM                               2604            0
# 1F_AUNT'S_APARTMENT                          2919            0
# 1F_BBQ                                       1375            0
# 1F_BBQ-1F_KITCHEN                               0            0
# 1F_BEDROOM                                   1274          339
# ...                                           ...          ...
# VENTILATION_ROOM-WORKSHOP                       0            0
# VISA_OFFICE                                   665            0
# WINE_CELLAR                                     0         1520
# WINE_CELLAR-SNOWMOBILE_GARAGE                   0            0
# WORKSHOP                                     5839         1728
#
# [142 rows x 15 columns]

# %%
# we can use this data and do any analysis we need
# checking Time expired is more in which objectivelocation
time_exp_obj = end_obj['TimeExpired'].sort_values(ascending = False)
time_exp_obj
# Out:
# objectivelocation
# KITCHEN                            3875
# VAULT                              3680
# MASTER_BEDROOM                     3410
# CHURCH                             2592
# ARMORY                             2591
#                                    ...
# DUMMY_DEPOT-STORAGE                   0
# DINING_ROOM-KIDS_BEDROOM              0
# DINING_HALL                           0
# CUSTOMS_INSPECTIONS-SUPPLY_ROOM       0
# 1F_ARMORY_ROOM                        0
# Name: TimeExpired, Length: 142, dtype: int64

# %%
plt.pie(time_exp_obj.head(5), labels = time_exp_obj.head(5).index, autopct="%1.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x148b1421c10>,
#   <matplotlib.patches.Wedge at 0x148b142d3a0>,
#   <matplotlib.patches.Wedge at 0x148b142dac0>,
#   <matplotlib.patches.Wedge at 0x148b1439220>,
#   <matplotlib.patches.Wedge at 0x148b1439970>],
#  [Text(0.8019416752072346, 0.7529206794648519, 'KITCHEN'),
#   Text(-0.6682501456631612, 0.8737515338018951, 'VAULT'),
#   Text(-0.9849376288598184, -0.4897936986691426, 'MASTER_BEDROOM'),
#   Text(0.06416495438866114, -1.098126977461305, 'CHURCH'),
#   Text(0.9631816499183486, -0.5313013356472651, 'ARMORY')],
#  [Text(0.43742273193121883, 0.41068400698082824, '24.00%'),
#   Text(-0.36450007945263335, 0.4765917457101245, '22.79%'),
#   Text(-0.53723870665081, -0.26716019927407775, '21.12%'),
#   Text(0.0349990660301788, -0.5989783513425299, '16.05%'),
#   Text(0.5253718090463719, -0.2898007285348719, '16.05%')])

# %%
#So these places need size increase to avoid time getting over as end round reason and also we could set a threshold instead of top 5

# %%
# Attackers surrendered and defenders surrendered
att_sur_obj = end_obj['AttackersSurrendered'].sort_values(ascending = False)
plt.pie(att_sur_obj.head(5), labels = att_sur_obj.head(5).index, autopct="%1.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x148b1480a30>,
#   <matplotlib.patches.Wedge at 0x148b148f1c0>,
#   <matplotlib.patches.Wedge at 0x148b148f910>,
#   <matplotlib.patches.Wedge at 0x148b1499070>,
#   <matplotlib.patches.Wedge at 0x148b1499790>],
#  [Text(0.7389123192762674, 0.8148672188901499, 'GARAGE'),
#   Text(-0.8483468273060901, 0.7002197230867544, 'ARCHIVES'),
#   Text(-0.8860934787828263, -0.651796246428705, 'MASTER_BEDROOM'),
#   Text(0.1445651872499553, -1.090459034826795, 'WORKSHOP'),
#   Text(0.9876576718937112, -0.4842853736687641, 'LIBRARY')],
#  [Text(0.4030430832416004, 0.44447302848553627, '26.55%'),
#   Text(-0.4627346330760491, 0.38193803077459326, '24.93%'),
#   Text(-0.4833237156997233, -0.3555252253247482, '17.23%'),
#   Text(0.0788537384999756, -0.5947958371782518, '16.78%'),
#   Text(0.5387223664874787, -0.2641556583647804, '14.51%')])

# %%
#These can be made easy to attack

# %%
def_sur_obj = end_obj['DefendersSurrendered'].sort_values(ascending = False)
plt.pie(def_sur_obj.head(5), labels = def_sur_obj.head(5).index, autopct="%1.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x148b14de8b0>,
#   <matplotlib.patches.Wedge at 0x148b14ee070>,
#   <matplotlib.patches.Wedge at 0x148b14ee790>,
#   <matplotlib.patches.Wedge at 0x148b14eeeb0>,
#   <matplotlib.patches.Wedge at 0x148b14fd610>],
#  [Text(0.6562493337772012, 0.8828005504738767, 'GARAGE'),
#   Text(-0.9189754782786367, 0.604552785389788, 'ARCHIVES'),
#   Text(-0.8845899314456604, -0.6538353410339349, 'SNOWMOBILE_GARAGE'),
#   Text(0.10202331056328078, -1.0952585284313967, 'LOCKERS'),
#   Text(0.9724935478300567, -0.5140586536854617, '2F_WORK_OFFICE')],
#  [Text(0.35795418206029156, 0.4815275729857509, '29.65%'),
#   Text(-0.5012593517883472, 0.3297560647580661, '22.17%'),
#   Text(-0.4825035989703602, -0.3566374587457826, '16.61%'),
#   Text(0.05564907848906223, -0.5974137427807618, '16.09%'),
#   Text(0.5304510260891218, -0.28039562928297906, '15.48%')])

# %%
#These objectives can be made easy to defend

# %%
# comparing AttackersKilledHostage and DefendersKilledHostage
att_kill_hos = end_obj['AttackersKilledHostage']
def_kill_hos = end_obj['DefendersKilledHostage']
plt.plot(att_kill_hos,def_kill_hos,'g+')
plt.title('AttackersKilledHostage Vs DefendersKilledHostage')
plt.xlabel('AttackersKilledHostage')
plt.ylabel('DefendersKilledHostage')
# Out:
# Text(0, 0.5, 'DefendersKilledHostage')

# %%
#we can see that It is almost the same number of times hostage was killed by both attackers and defenders

# %%
#Finding the correlation between all of them
df.drop(['dateid','matchid'],axis=1).corr()
# Out:
#                 roundnumber  roundduration  clearancelevel      team  \
# roundnumber        1.000000       0.005309        0.025621 -0.000821
# roundduration      0.005309       1.000000        0.055102 -0.000150
# clearancelevel     0.025621       0.055102        1.000000  0.008847
# team              -0.000821      -0.000150        0.008847  1.000000
# haswon             0.004358      -0.011683        0.025301 -0.005644
# nbkills           -0.003359       0.060025        0.069960 -0.002974
# isdead            -0.005923       0.118866       -0.017778  0.005273
#
#                   haswon   nbkills    isdead
# roundnumber     0.004358 -0.003359 -0.005923
# roundduration  -0.011683  0.060025  0.118866
# clearancelevel  0.025301  0.069960 -0.017778
# team           -0.005644 -0.002974  0.005273
# haswon          1.000000  0.249184 -0.564573
# nbkills         0.249184  1.000000 -0.365543
# isdead         -0.564573 -0.365543  1.000000

# %%
#For a better understanding of correlation using heatmap
fig, ax = plt.subplots(figsize=(20, 20))
sns.heatmap(df.drop(['dateid','matchid'],axis=1).corr(),cmap = 'Greens',annot=True)
# Out:
# <AxesSubplot:>

# %%
#Which primary weapon type is frequently used and least preferred
sns.countplot(y ='primaryweapontype', data = df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='primaryweapontype'>

# %%
# we can see that Light maachine guns are least preffered(needs buff) and assault rifles are most preffered ones(needs nerf)

# %%
#finding the most prefferd primary weapon secondry weapon combo using number of kills as a criteria
pd.pivot_table(df,index=['primaryweapon', 'secondaryweapon'],values='nbkills',aggfunc = 'sum').sort_values('nbkills',ascending=False)
# Out:
#                                nbkills
# primaryweapon secondaryweapon
# 416-C_CARBINE P12               436515
# MP7           P12               284899
# TYPE-89       BEARING_9         256787
# R4-C          M45_MEUSOC        218795
# MPX           D-50              199512
# ...                                ...
# Shield        GSH-18              1925
# ITA12L        ITA12S              1842
# MP5K          SMG-11              1476
# AR33          SMG-11               910
# SuperNova     P229                 619
#
# [77 rows x 1 columns]

# %%
# we can clearly see that 416-C_CARBINE and P12 combo is very powerful compared to others so some nerf should take place
# Also we can see that SuperNova and p229 is at the last so some buff can be given in the future patch

# %%
df.skillrank.unique()
# Out:
# array(['Gold', 'Platinum', 'Diamond', 'Unranked', 'Silver', 'Bronze',
#        'Copper'], dtype=object)

# %%
df.haswon.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.haswon = df.haswon.map({0:'Lost', 1:'Won'})

# %%
df.haswon.unique()
# Out:
# array(['Lost', 'Won'], dtype=object)

# %%
#comparing the skill rank with the winning and losing

won = df[df['haswon'] == 'Won']
lost = df[df['haswon'] == 'Lost']


y = np.arange(7)
won_count = won.groupby('skillrank')['haswon'].count()
lost_count = lost.groupby('skillrank')['haswon'].count()
width = 0.2

fig, ax = plt.subplots()
rects1 = ax.barh(y - width, won_count, width, label='Won', color = 'Green')
rects2 = ax.barh(y + width, lost_count, width, label='Lost', color = 'orange')


ax.set_title('SkillRank Vs Won/lost')
ax.set_yticks(y, df.skillrank.unique())
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.set_xlabel('Count')
fig.tight_layout()

plt.show()

# %%
# We can see that its almost the same won/lost times

# %%
#This is the end of my analysis
